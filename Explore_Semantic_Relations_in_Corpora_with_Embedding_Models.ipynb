# %% [markdown]
# <a href="https://colab.research.google.com/github/kstyle2198/NLP_TIPS/blob/main/Explore_Semantic_Relations_in_Corpora_with_Embedding_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://medium.com/towards-data-science/explore-semantic-relations-in-corpora-with-embedding-models-0a6d64c3ec7f

# %%
# !pip install glovpy gensim scikit-learn
# Out:
# Collecting glovpy
#   Downloading glovpy-0.2.0-py3-none-any.whl (7.7 kB)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.23.5)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Installing collected packages: glovpy
# Successfully installed glovpy-0.2.0

# %%
from gensim.utils import tokenize
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS

# %%
def clean_tokenize(text: str) -> list[str]:
    """This function tokenizes texts and removes stop words from them"""
    tokens = tokenize(text, lower=True, deacc=True)
    tokens = [token for token in tokens if token not in ENGLISH_STOP_WORDS]
    return tokens

# %%
# Loading the dataset
dataset = fetch_20newsgroups(
    remove=("headers", "footers", "quotes"), categories=["sci.med"]
)
newsgroups = dataset.data
len(newsgroups)
# Out:
# 594

# %%
# Tokenizing the dataset
tokenized_corpus = [clean_tokenize(text) for text in newsgroups]
len(tokenized_corpus)
# Out:
# 594

# %%
tokenized_corpus[0]
# Out:
# ['reply',
#  'keith',
#  'actrix',
#  'gen',
#  'nz',
#  'keith',
#  'stewart',
#  'help',
#  'asking',
#  'medical',
#  'information',
#  'subject',
#  'ask',
#  'specific',
#  'questions',
#  'likely',
#  'type',
#  'textbook',
#  'chapter',
#  'covering',
#  'aspects',
#  'subject',
#  'looking',
#  'comprehensive',
#  'review',
#  'ask',
#  'local',
#  'hospital',
#  'librarian',
#  'happy',
#  'help',
#  'request',
#  'sort',
#  'briefly',
#  'condition',
#  'patients',
#  'significant',
#  'residual',
#  'weakness',
#  'childhood',
#  'polio',
#  'notice',
#  'progression',
#  'weakness',
#  'older',
#  'theory',
#  'remaining',
#  'motor',
#  'neurons',
#  'work',
#  'harder',
#  'die',
#  'sooner']

# %%
from glovpy import GloVe

# %%
# Training word embeddings
model = GloVe(vector_size=25)
model.train(tokenized_corpus)
# Out:
# Collecting Vocabulary...
# Collecting cooccurrences...
# Shuffling cooccurrences...
# Training model...

# %%
model.wv.most_similar("child")
# Out:
# [('adult', 0.9202715158462524),
#  ('restraint', 0.9079991579055786),
#  ('consistent', 0.8805399537086487),
#  ('hand', 0.874118447303772),
#  ('children', 0.8557751178741455),
#  ('belt', 0.8536299467086792),
#  ('use', 0.8462283611297607),
#  ('age', 0.8388909697532654),
#  ('safety', 0.8354132771492004),
#  ('law', 0.8179876208305359)]

# %%
# !pip install embedding_explorer
# Out:
# Collecting embedding_explorer
#   Downloading embedding_explorer-0.5.2-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 782.3 kB/s eta 0:00:00
# Collecting dash<3.0.0,>=2.11.1 (from embedding_explorer)
#   Downloading dash-2.14.2-py3-none-any.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 30.1 MB/s eta 0:00:00
# Collecting dash-extensions<0.2.0,>=0.1.10 (from embedding_explorer)
#   Downloading dash_extensions-0.1.13-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 87.2 MB/s eta 0:00:00
# Collecting dash-iconify<0.2.0,>=0.1.2 (from embedding_explorer)
#   Downloading dash_iconify-0.1.2-py3-none-any.whl (18 kB)
# Collecting dash-mantine-components<0.12.0,>=0.11.1 (from embedding_explorer)
#   Downloading dash_mantine_components-0.11.1-py3-none-any.whl (443 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.1/443.1 kB 53.1 MB/s eta 0:00:00
# Collecting hdbscan>=0.8.30 (from embedding_explorer)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 51.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting kaleido>=0.2.1 (from embedding_explorer)
#   Downloading kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 10.0 MB/s eta 0:00:00
# Collecting neofuzz>=0.1.2 (from embedding_explorer)
#   Downloading neofuzz-0.1.3-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from embedding_explorer) (1.23.5)
# Requirement already satisfied: pandas>=1.5.2 in /usr/local/lib/python3.10/dist-packages (from embedding_explorer) (1.5.3)
# Requirement already satisfied: plotly<6.0.0,>=5.14.0 in /usr/local/lib/python3.10/dist-packages (from embedding_explorer) (5.15.0)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from embedding_explorer) (1.2.2)
# Collecting umap-learn>=0.5.0 (from embedding_explorer)
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wordcloud<2.0.0.0,>=1.8.2.2 in /usr/local/lib/python3.10/dist-packages (from embedding_explorer) (1.9.3)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.1->embedding_explorer) (2.2.5)
# Requirement already satisfied: Werkzeug<3.1 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.1->embedding_explorer) (3.0.1)
# Collecting dash-html-components==2.0.0 (from dash<3.0.0,>=2.11.1->embedding_explorer)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Collecting dash-core-components==2.0.0 (from dash<3.0.0,>=2.11.1->embedding_explorer)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Collecting dash-table==5.0.0 (from dash<3.0.0,>=2.11.1->embedding_explorer)
#   Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.1->embedding_explorer) (4.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.1->embedding_explorer) (2.31.0)
# Collecting retrying (from dash<3.0.0,>=2.11.1->embedding_explorer)
#   Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Collecting ansi2html (from dash<3.0.0,>=2.11.1->embedding_explorer)
#   Downloading ansi2html-1.9.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.1->embedding_explorer) (1.5.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.1->embedding_explorer) (67.7.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.10/dist-packages (from dash<3.0.0,>=2.11.1->embedding_explorer) (7.0.0)
# Collecting Flask-Caching==2.0.2 (from dash-extensions<0.2.0,>=0.1.10->embedding_explorer)
#   Downloading Flask_Caching-2.0.2-py3-none-any.whl (28 kB)
# Collecting jsbeautifier<2.0.0,>=1.14.3 (from dash-extensions<0.2.0,>=0.1.10->embedding_explorer)
#   Downloading jsbeautifier-1.14.11.tar.gz (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting more-itertools<10.0.0,>=9.0.0 (from dash-extensions<0.2.0,>=0.1.10->embedding_explorer)
#   Downloading more_itertools-9.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 8.5 MB/s eta 0:00:00
# Collecting cachelib<0.10.0,>=0.9.0 (from Flask-Caching==2.0.2->dash-extensions<0.2.0,>=0.1.10->embedding_explorer)
#   Downloading cachelib-0.9.0-py3-none-any.whl (15 kB)
# Collecting cython<3,>=0.27 (from hdbscan>=0.8.30->embedding_explorer)
#   Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.30->embedding_explorer) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.30->embedding_explorer) (1.3.2)
# Collecting pynndescent<0.6.0,>=0.5.0 (from neofuzz>=0.1.2->embedding_explorer)
#   Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.2->embedding_explorer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.5.2->embedding_explorer) (2023.3.post1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly<6.0.0,>=5.14.0->embedding_explorer) (8.2.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly<6.0.0,>=5.14.0->embedding_explorer) (23.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<2.0.0,>=1.1.0->embedding_explorer) (3.2.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->embedding_explorer) (0.58.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->embedding_explorer) (4.66.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud<2.0.0.0,>=1.8.2.2->embedding_explorer) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud<2.0.0.0,>=1.8.2.2->embedding_explorer) (3.7.1)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=2.11.1->embedding_explorer) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=2.11.1->embedding_explorer) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from Flask<3.1,>=1.0.4->dash<3.0.0,>=2.11.1->embedding_explorer) (8.1.7)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from jsbeautifier<2.0.0,>=1.14.3->dash-extensions<0.2.0,>=0.1.10->embedding_explorer) (1.16.0)
# Collecting editorconfig>=0.12.2 (from jsbeautifier<2.0.0,>=1.14.3->dash-extensions<0.2.0,>=0.1.10->embedding_explorer)
#   Downloading EditorConfig-0.12.3-py3-none-any.whl (16 kB)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->embedding_explorer) (0.41.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from Werkzeug<3.1->dash<3.0.0,>=2.11.1->embedding_explorer) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata->dash<3.0.0,>=2.11.1->embedding_explorer) (3.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud<2.0.0.0,>=1.8.2.2->embedding_explorer) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud<2.0.0.0,>=1.8.2.2->embedding_explorer) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud<2.0.0.0,>=1.8.2.2->embedding_explorer) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud<2.0.0.0,>=1.8.2.2->embedding_explorer) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud<2.0.0.0,>=1.8.2.2->embedding_explorer) (3.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dash<3.0.0,>=2.11.1->embedding_explorer) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dash<3.0.0,>=2.11.1->embedding_explorer) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dash<3.0.0,>=2.11.1->embedding_explorer) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dash<3.0.0,>=2.11.1->embedding_explorer) (2023.11.17)
# Building wheels for collected packages: hdbscan, umap-learn, jsbeautifier
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039275 sha256=bf242c93208250a2b50cf44e3ba40d6cbc20300442b97a2dbfc1a39d649e3e0c
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=8c33684501c554f9df93a62f004880e736d9ee63595c8222e04c2c1ac7a5faeb
#   Stored in directory: /root/.cache/pip/wheels/3a/70/07/428d2b58660a1a3b431db59b806a10da736612ebbc66c1bcc5
#   Building wheel for jsbeautifier (pyproject.toml) ... done
#   Created wheel for jsbeautifier: filename=jsbeautifier-1.14.11-py3-none-any.whl size=94685 sha256=624e61cddf9aaf8a671bc3e27cc37af2dab0070fb7a417f7160b81976a568fb6
#   Stored in directory: /root/.cache/pip/wheels/82/3b/fd/d6ed4d0751dfbbf312941f1ff830a41407b8d827a89a085181
# Successfully built hdbscan umap-learn jsbeautifier
# Installing collected packages: kaleido, editorconfig, dash-table, dash-mantine-components, dash-iconify, dash-html-components, dash-core-components, retrying, more-itertools, jsbeautifier, cython, cachelib, ansi2html, pynndescent, hdbscan, Flask-Caching, dash, umap-learn, neofuzz, dash-extensions, embedding_explorer
#   Attempting uninstall: more-itertools
#     Found existing installation: more-itertools 10.1.0
#     Uninstalling more-itertools-10.1.0:
#       Successfully uninstalled more-itertools-10.1.0
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.6
#     Uninstalling Cython-3.0.6:
#       Successfully uninstalled Cython-3.0.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# Successfully installed Flask-Caching-2.0.2 ansi2html-1.9.1 cachelib-0.9.0 cython-0.29.37 dash-2.14.2 dash-core-components-2.0.0 dash-extensions-0.1.13 dash-html-components-2.0.0 dash-iconify-0.1.2 dash-mantine-components-0.11.1 dash-table-5.0.0 editorconfig-0.12.3 embedding_explorer-0.5.2 hdbscan-0.8.33 jsbeautifier-1.14.11 kaleido-0.2.1 more-itertools-9.1.0 neofuzz-0.1.3 pynndescent-0.5.11 retrying-1.3.4 umap-learn-0.5.5

# %%
from embedding_explorer import show_network_explorer

vocabulary = model.wv.index_to_key
embeddings = model.wv.vectors
show_network_explorer(vocabulary, embeddings=embeddings)
# Out:
# Creating explorer with name:
# <Thread(Thread-10 (_run_silent), stopped 140254591649344)>

# %%
from sklearn.feature_extraction.text import CountVectorizer

# First we train a model on the corpus that learns all 4-grams
# We will only take the 4000 most frequent ones into account for now,
# But you can freely experiment with this
feature_extractor = CountVectorizer(ngram_range=(4,4), max_features=4000)
feature_extractor.fit(newsgroups)
# Then we get the vectorizer's vocabulary
four_grams = feature_extractor.get_feature_names_out()

# %%
# !pip install embetter[text]
# Out:
# Collecting embetter[text]
#   Downloading embetter-0.6.0-py2.py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 476.1 kB/s eta 0:00:00
# Requirement already satisfied: diskcache>=5.6.1 in /usr/local/lib/python3.10/dist-packages (from embetter[text]) (5.6.3)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from embetter[text]) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from embetter[text]) (1.2.2)
# Collecting skops>=0.8.0 (from embetter[text])
#   Downloading skops-0.9.0-py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 kB 2.1 MB/s eta 0:00:00
# Collecting bpemb>=0.3.3 (from embetter[text])
#   Downloading bpemb-0.3.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: gensim>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from embetter[text]) (4.3.2)
# Collecting keras-nlp>=0.6.0 (from embetter[text])
#   Downloading keras_nlp-0.6.4-py3-none-any.whl (584 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.8/584.8 kB 6.9 MB/s eta 0:00:00
# Collecting sense2vec==2.0.0 (from embetter[text])
#   Downloading sense2vec-2.0.0-py2.py3-none-any.whl (39 kB)
# Collecting sentence-transformers>=2.2.2 (from embetter[text])
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: spacy<4.0.0,>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from sense2vec==2.0.0->embetter[text]) (3.6.1)
# Collecting wasabi<1.1.0,>=0.8.1 (from sense2vec==2.0.0->embetter[text])
#   Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from sense2vec==2.0.0->embetter[text]) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from sense2vec==2.0.0->embetter[text]) (2.0.10)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from sense2vec==2.0.0->embetter[text]) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bpemb>=0.3.3->embetter[text]) (2.31.0)
# Collecting sentencepiece (from bpemb>=0.3.3->embetter[text])
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from bpemb>=0.3.3->embetter[text]) (4.66.1)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.3.1->embetter[text]) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.3.1->embetter[text]) (6.4.0)
# Collecting keras-core (from keras-nlp>=0.6.0->embetter[text])
#   Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 53.6 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-nlp>=0.6.0->embetter[text]) (1.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-nlp>=0.6.0->embetter[text]) (23.2)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras-nlp>=0.6.0->embetter[text]) (2023.6.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-nlp>=0.6.0->embetter[text]) (13.7.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-nlp>=0.6.0->embetter[text]) (0.1.8)
# Collecting tensorflow-text (from keras-nlp>=0.6.0->embetter[text])
#   Downloading tensorflow_text-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 47.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->embetter[text]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->embetter[text]) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->embetter[text]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->embetter[text]) (3.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->embetter[text]) (4.35.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->embetter[text]) (2.1.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->embetter[text]) (0.16.0+cu121)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->embetter[text]) (3.8.1)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.2->embetter[text]) (0.19.4)
# Requirement already satisfied: tabulate>=0.8.8 in /usr/local/lib/python3.10/dist-packages (from skops>=0.8.0->embetter[text]) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->embetter[text]) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->embetter[text]) (2023.6.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->embetter[text]) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=2.2.2->embetter[text]) (4.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0.0->embetter[text]) (1.16.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (8.1.12)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (0.10.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (67.7.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.3->embetter[text]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.3->embetter[text]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.3->embetter[text]) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bpemb>=0.3.3->embetter[text]) (2023.11.17)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->embetter[text]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->embetter[text]) (3.2.1)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers>=2.2.2->embetter[text]) (2.1.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->embetter[text]) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=2.2.2->embetter[text]) (0.4.1)
# Collecting namex (from keras-core->keras-nlp>=0.6.0->embetter[text])
#   Downloading namex-0.0.7-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras-nlp>=0.6.0->embetter[text]) (3.9.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=2.2.2->embetter[text]) (8.1.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nlp>=0.6.0->embetter[text]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-nlp>=0.6.0->embetter[text]) (2.16.1)
# Requirement already satisfied: tensorflow-hub>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (0.15.0)
# Requirement already satisfied: tensorflow<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (2.15.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers>=2.2.2->embetter[text]) (9.4.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-nlp>=0.6.0->embetter[text]) (0.1.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (3.20.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (2.4.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (1.60.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (2.15.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (0.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<4.0.0,>=3.0.0->sense2vec==2.0.0->embetter[text]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers>=2.2.2->embetter[text]) (1.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (0.42.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (3.5.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow<2.16,>=2.15.0->tensorflow-text->keras-nlp>=0.6.0->embetter[text]) (3.2.2)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=1152f0cde7f6d405606b5b93f6f439f011b1a87e36594f8b3da3b5253b64845b
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: wasabi, sentencepiece, namex, skops, keras-core, bpemb, embetter, sentence-transformers, sense2vec, tensorflow-text, keras-nlp
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.2
#     Uninstalling wasabi-1.1.2:
#       Successfully uninstalled wasabi-1.1.2
# Successfully installed bpemb-0.3.4 embetter-0.6.0 keras-core-0.1.7 keras-nlp-0.6.4 namex-0.0.7 sense2vec-2.0.0 sentence-transformers-2.2.2 sentencepiece-0.1.99 skops-0.9.0 tensorflow-text-2.15.0 wasabi-0.10.1

# %%
from embetter.text import SentenceEncoder

encoder = SentenceEncoder("all-MiniLM-L6-v2")
# Out:
# Using TensorFlow backend
# .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
from embedding_explorer import show_network_explorer

show_network_explorer(four_grams, vectorizer=encoder)
# Out:
# Creating explorer with name:
# Open in browser:
# <Thread(Thread-55 (_run_silent), stopped 140250623358528)>

# %%
import pandas as pd
import numpy as np

corpus = tokenized_corpus

# Extracting text lengths in number of characters.
lengths = [len(text) for text in corpus]

# Extracting first 400 characters from each text.
text_starts = [text[:400] for text in corpus]

# Extracting the group each text belongs to
# Sklearn gives the labels back as integers, we have to map them back to
# the actual textual label.
group_labels = np.array(dataset.target_names)[dataset.target]

# We build a dataframe with the available metadata
metadata = pd.DataFrame(dict(length=lengths, text=text_starts, group=group_labels))

# %%
metadata.head()
# Out:
#    length                                               text    group
# 0      53  [reply, keith, actrix, gen, nz, keith, stewart...  sci.med
# 1      41  [allergy, shots, years, starting, sophomore, h...  sci.med
# 2     135  [vida, develop, inner, ear, problems, flying, ...  sci.med
# 3      73  [rousseaua, immunex, com, writes, heat, shock,...  sci.med
# 4     104  [probably, years, possible, disassemble, assem...  sci.med

# %%
metadata.group.unique()
# Out:
# array(['sci.med'], dtype=object)

# %%
from embedding_explorer import show_clustering

show_clustering(
  newsgroups,
  vectorizer=encoder,
  metadata=metadata,
  hover_name="group", # Title of hover box is going to be the group
  hover_data=["text", "length"] # We would also like to see these on hover
)
# Out:
# Open in browser:
# <Thread(Thread-77 (_run_silent), stopped 140250623358528)>
